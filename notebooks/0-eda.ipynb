# %% [markdown]
# # EDA
#
# This notebook is a starter for exploratory data analysis on pill images.
#
# * Steps to add:
#   - Mount dataset and inspect image counts per class
#   - Visualize random samples and image sizes
#   - Compute class imbalance and duplicate detection
#   - Save a cleaned subset for model development
